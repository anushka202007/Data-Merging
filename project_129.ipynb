# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka202007/Data-Merging/blob/main/project_129.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/procodingclass/PRO-Stars-Dataset-CSVs
# Out:
# Cloning into 'PRO-Stars-Dataset-CSVs'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 26 (delta 10), reused 12 (delta 5), pack-reused 0
# Receiving objects: 100% (26/26), 27.77 KiB | 1.63 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/PRO-Stars-Dataset-CSVs/dwarf_stars.csv")

# %%
df= df.dropna()

# %%
df.head()
# Out:
#    id                      Star_name  Distance Mass  Radius
# 0   0  SDSS J000013.54+255418.6 [de]      46.1   48    0.99
# 1   1        2MASS J00040288-6410358     192.0   19    1.63
# 3   3        2MASS J00242463-0158201      37.7   79    1.09
# 5   5        2MASS J00274197+0503417     236.0   31    1.44
# 7   7         2MASSW J0030300-145033      87.2   54    0.98

# %%
df.Mass=df.Mass.str.replace('[^a-zA-Z0-9]','').astype('float')
# Out:
# <ipython-input-6-ae16b751e278>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.Mass=df.Mass.str.replace('[^a-zA-Z0-9]','').astype('float')

# %%
df['Radius']=df['Radius']*(0.102763)
df['Mass']=df['Mass']*(0.000954588)

# %%
df.to_csv('dwraf_stars.csv')

# %%
df=pd.read_csv('dwraf_stars.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  id                      Star_name  Distance      Mass    Radius
# 0           0   0  SDSS J000013.54+255418.6 [de]      46.1  0.045820  0.101735
# 1           1   1        2MASS J00040288-6410358     192.0  0.018137  0.167504
# 2           3   3        2MASS J00242463-0158201      37.7  0.075412  0.112012
# 3           5   5        2MASS J00274197+0503417     236.0  0.029592  0.147979
# 4           7   7         2MASSW J0030300-145033      87.2  0.051548  0.100708

# %%
bright_stars=pd.read_csv('/content/PRO-Stars-Dataset-CSVs/bright_stars.csv')

# %%
bright_stars.head()
# Out:
#    id       Star_name     Distance Mass Radius Luminosity
# 0   0             Sun  0.000015813    1      1          1
# 1   1          Sirius       0008.6  2.1   1.71       25.4
# 2   2         Canopus         0310   15     71     13,500
# 3   3  Alpha Centauri       0004.4  1.1    1.2          2
# 4   4        Arcturus         0037  1.1     26        170

# %%
import csv
import pandas as pd

file1 = '/content/PRO-Stars-Dataset-CSVs/bright_stars.csv'
file2 = '/content/PRO-Stars-Dataset-CSVs/dwarf_stars.csv'

d1 = []
d2 = []
with open(file1,'r',encoding='utf8') as f:
    csv_reader =csv.reader(f)

    for i in csv_reader:
        d1.append(i)

with open(file2,'r',encoding='utf8') as f:
    csv_reader = csv.reader(f)

    for i in csv_reader:
        d2.append(i)

h1 = d1[0]
h2 = d2[0]

p_d1 = d1[1:]
p_d2 = d2[1:]

h = h1+h2

p_d =[]

for i in p_d1:
    p_d.append(i)
for j in p_d2:
    p_d.append(j)

# %%
with open("total_stars.csv",'w',encoding='utf8') as f:
    csvwriter = csv.writer(f)
    csvwriter.writerow(h)
    csvwriter.writerows(p_d)

df = pd.read_csv('total_stars.csv')
df.tail(8)

from google.colab import files
files.download("total_stars.csv")
